# %%
import pandas as pd
import pymongo

df=pd.read_csv("./data/data.csv")
df.head()
# Out:
#                                           house_type       locality    city  \
# 0  2 BHK Flat for Rent in Oberoi Woods, Goregaon ...  Goregaon East  Mumbai
# 1  1 BHK Flat for Rent in Sapphire Lakeside, Powa...          Powai  Mumbai
# 2               1 BHK House for Rent in Mundhwa Pune        Mundhwa    Pune
# 3              2 BHK Flat for Rent in Hingna, Nagpur         Hingna  Nagpur
# 4  1 BHK Flat for Rent in Unique Star Harsh Vihar...      Mira Road  Mumbai
#
#      area  beds  bathrooms  balconies      furnishing  area_rate      rent
# 0   897.0     2          2          0  Semi-Furnished      134.0  120000.0
# 1   490.0     1          1          0  Semi-Furnished       82.0   40000.0
# 2   550.0     1          1          0     Unfurnished       22.0   12000.0
# 3  1000.0     2          2          0     Unfurnished        8.0    8000.0
# 4   595.0     1          1          0     Unfurnished       25.0   15000.0

# %%
data=df.to_dict(orient='records')

# %%
data
# Out:
# [{'house_type': '2 BHK Flat for Rent in Oberoi Woods, Goregaon East, Mumbai',
#   'locality': 'Goregaon East',
#   'city': 'Mumbai',
#   'area': 897.0,
#   'beds': 2,
#   'bathrooms': 2,
#   'balconies': 0,
#   'furnishing': 'Semi-Furnished',
#   'area_rate': 134.0,
#   'rent': 120000.0},
#  {'house_type': '1 BHK Flat for Rent in Sapphire Lakeside, Powai, Mumbai',
#   'locality': 'Powai',
#   'city': 'Mumbai',
#   'area': 490.0,
#   'beds': 1,
#   'bathrooms': 1,
#   'balconies': 0,
#   'furnishing': 'Semi-Furnished',
#   'area_rate': 82.0,
#   'rent': 40000.0},
#  {'house_type': '1 BHK House for Rent in Mundhwa Pune',
#   'locality': 'Mundhwa',
#   'city': 'Pune',
#   'area': 550.0,
#   'beds': 1,
#   'bathrooms': 1,
#   'balconies': 0,
#   'furnishing': 'Unfurnished',
#   'area_rate': 22.0,
#   'rent': 12000.0},
#  {'house_type': '2 BHK Flat for Rent in Hingna, Nagpur',
#   'locality': 'Hingna',
#   'city': 'Nagpur',
#   'area': 1000.0,
#   'beds': 2,
#   'bathrooms': 2,
# ...

# %%
DB_NAME="Proj1"
COLLECTION_NAME="Proj1-Data"
CONNECTION_URI="mongodb+srv://vanshsharma7832_db_user:ieYqb2I8PG1rycGO@insuranccluster0.2wrgwjg.mongodb.net/?appName=InsurancCluster0"

# %%
client=pymongo.MongoClient(CONNECTION_URI)
data_base=client[DB_NAME]

cllection=data_base[COLLECTION_NAME]

# %%
client
# Out:
# MongoClient(host=['ac-i2qgmps-shard-00-02.2wrgwjg.mongodb.net:27017', 'ac-i2qgmps-shard-00-01.2wrgwjg.mongodb.net:27017', 'ac-i2qgmps-shard-00-00.2wrgwjg.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, appname='InsurancCluster0', authsource='admin', replicaset='atlas-dcuge3-shard-0', tls=True)

# %%
data_base
# Out:
# Database(MongoClient(host=['ac-i2qgmps-shard-00-02.2wrgwjg.mongodb.net:27017', 'ac-i2qgmps-shard-00-01.2wrgwjg.mongodb.net:27017', 'ac-i2qgmps-shard-00-00.2wrgwjg.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, appname='InsurancCluster0', authsource='admin', replicaset='atlas-dcuge3-shard-0', tls=True), 'Proj1')

# %%
cllection
# Out:
# Collection(Database(MongoClient(host=['ac-i2qgmps-shard-00-02.2wrgwjg.mongodb.net:27017', 'ac-i2qgmps-shard-00-01.2wrgwjg.mongodb.net:27017', 'ac-i2qgmps-shard-00-00.2wrgwjg.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, appname='InsurancCluster0', authsource='admin', replicaset='atlas-dcuge3-shard-0', tls=True), 'Proj1'), 'Proj1-Data')

# %%
res=cllection.insert_many(data)

# %%
res
# Out:
# InsertManyResult([ObjectId('697ed8a2c1b022ba044a1306'), ObjectId('697ed8a2c1b022ba044a1307'), ObjectId('697ed8a2c1b022ba044a1308'), ObjectId('697ed8a2c1b022ba044a1309'), ObjectId('697ed8a2c1b022ba044a130a'), ObjectId('697ed8a2c1b022ba044a130b'), ObjectId('697ed8a2c1b022ba044a130c'), ObjectId('697ed8a2c1b022ba044a130d'), ObjectId('697ed8a2c1b022ba044a130e'), ObjectId('697ed8a2c1b022ba044a130f'), ObjectId('697ed8a2c1b022ba044a1310'), ObjectId('697ed8a2c1b022ba044a1311'), ObjectId('697ed8a2c1b022ba044a1312'), ObjectId('697ed8a2c1b022ba044a1313'), ObjectId('697ed8a2c1b022ba044a1314'), ObjectId('697ed8a2c1b022ba044a1315'), ObjectId('697ed8a2c1b022ba044a1316'), ObjectId('697ed8a2c1b022ba044a1317'), ObjectId('697ed8a2c1b022ba044a1318'), ObjectId('697ed8a2c1b022ba044a1319'), ObjectId('697ed8a2c1b022ba044a131a'), ObjectId('697ed8a2c1b022ba044a131b'), ObjectId('697ed8a2c1b022ba044a131c'), ObjectId('697ed8a2c1b022ba044a131d'), ObjectId('697ed8a2c1b022ba044a131e'), ObjectId('697ed8a2c1b022ba044a
# ...

# %%
cllection.find()

# %%
list(cllection.find())
# Out:
# [{'_id': ObjectId('697ed8a2c1b022ba044a1306'),
#   'house_type': '2 BHK Flat for Rent in Oberoi Woods, Goregaon East, Mumbai',
#   'locality': 'Goregaon East',
#   'city': 'Mumbai',
#   'area': 897.0,
#   'beds': 2,
#   'bathrooms': 2,
#   'balconies': 0,
#   'furnishing': 'Semi-Furnished',
#   'area_rate': 134.0,
#   'rent': 120000.0},
#  {'_id': ObjectId('697ed8a2c1b022ba044a1307'),
#   'house_type': '1 BHK Flat for Rent in Sapphire Lakeside, Powai, Mumbai',
#   'locality': 'Powai',
#   'city': 'Mumbai',
#   'area': 490.0,
#   'beds': 1,
#   'bathrooms': 1,
#   'balconies': 0,
#   'furnishing': 'Semi-Furnished',
#   'area_rate': 82.0,
#   'rent': 40000.0},
#  {'_id': ObjectId('697ed8a2c1b022ba044a1308'),
#   'house_type': '1 BHK House for Rent in Mundhwa Pune',
#   'locality': 'Mundhwa',
#   'city': 'Pune',
#   'area': 550.0,
#   'beds': 1,
#   'bathrooms': 1,
#   'balconies': 0,
#   'furnishing': 'Unfurnished',
#   'area_rate': 22.0,
#   'rent': 12000.0},
# ...

# %%
data=pd.DataFrame(list(cllection.find()))

# %%
data.head()
# Out:
#                         _id  \
# 0  697ed8a2c1b022ba044a1306
# 1  697ed8a2c1b022ba044a1307
# 2  697ed8a2c1b022ba044a1308
# 3  697ed8a2c1b022ba044a1309
# 4  697ed8a2c1b022ba044a130a
#
#                                           house_type       locality    city  \
# 0  2 BHK Flat for Rent in Oberoi Woods, Goregaon ...  Goregaon East  Mumbai
# 1  1 BHK Flat for Rent in Sapphire Lakeside, Powa...          Powai  Mumbai
# 2               1 BHK House for Rent in Mundhwa Pune        Mundhwa    Pune
# 3              2 BHK Flat for Rent in Hingna, Nagpur         Hingna  Nagpur
# 4  1 BHK Flat for Rent in Unique Star Harsh Vihar...      Mira Road  Mumbai
#
#      area  beds  bathrooms  balconies      furnishing  area_rate      rent
# 0   897.0     2          2          0  Semi-Furnished      134.0  120000.0
# 1   490.0     1          1          0  Semi-Furnished       82.0   40000.0
# 2   550.0     1          1          0     Unfurnished       22.0   12000.0
# ...
